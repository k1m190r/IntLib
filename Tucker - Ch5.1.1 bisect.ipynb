# %%
import numpy as np
from numpy import inf

from bokeh.plotting import figure, output_notebook, show
from bokeh.models import Span

output_notebook()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="c583c567-995c-41b1-8c54-c0233febefc3">Loading BokehJS ...</span>
#     </div>

# %%
# reload 

from importlib import reload

import IntLib
import AutoDiff
import GenFuncs

reload(IntLib)
reload(AutoDiff)
reload(GenFuncs)
# Out:
# <module 'GenFuncs' from 'c:\\Users\\k1m19\\OneDrive\\Desktop\\Numerical\\IntLib\\GenFuncs.py'>

# %%
from IntLib import (
    Interval,
    round_down,
    round_up,
    round_nearest,
    _pi_,
    _e_,
    _sqrt2_,
    _has_zero,
    _add,
    _sub,
    _mul,
    _div_simple,
    _div,
    _sqrt,
    _pow,
    _exp,
    _log,
    _sin,
    _cos,
)

from AutoDiff import (
    AutoDiff,
    _ensure_AD,
)

from GenFuncs import (
    mag,
    mig,
    sqrt,
    sin,
    cos,
    mid,
    rad,
    exp,
    log,
    atan,
)


IA = Interval
AD = AutoDiff

# %% [markdown]
# # TODO
# - tests
# - deal with empty set
# - extened division ?
# - numpy arrays...

# %% [markdown]
# # Bisect method for root finding

# %%
roots = []
icount = 0


def bisect(f, x: Interval, tol):
    global roots, icount
    icount += 1
    if f(x).has_zero:
        diam = x.rad * 2
        if diam < tol:
            roots.append(x)
        else:
            _x, x_ = x
            m = x.mid
            bisect(f, IA(_x, m), tol)
            bisect(f, IA(m, x_), tol)


def f(x):
    return sin(x) * (x - cos(x))


bisect(f, IA(-10, 10), 0.2)
icount, roots, len(roots)
# Out:
# (83,
#  [[-9.53125₀₀₀₀₀₀₀₀₀₀₀₀, -9.375₀₀₀₀₀₀₀₀₀₀₀₀₀₀],
#   [-6.4₀625₀₀₀₀₀₀₀₀₀₀₀₀, -6.25₀₀₀₀₀₀₀₀₀₀₀₀₀₀₀],
#   [-3.28125₀₀₀₀₀₀₀₀₀₀₀₀, -3.125₀₀₀₀₀₀₀₀₀₀₀₀₀₀],
#   [-₀.15625₀₀₀₀₀₀₀₀₀₀₀₀, +₀.₀₀₀₀₀₀₀₀₀₀₀₀₀₀₀₀₀],
#   [+₀.₀₀₀₀₀₀₀₀₀₀₀₀₀₀₀₀₀, +₀.15625₀₀₀₀₀₀₀₀₀₀₀₀],
#   [+₀.625₀₀₀₀₀₀₀₀₀₀₀₀₀₀, +₀.78125₀₀₀₀₀₀₀₀₀₀₀₀],
#   [+3.125₀₀₀₀₀₀₀₀₀₀₀₀₀₀, +3.28125₀₀₀₀₀₀₀₀₀₀₀₀],
#   [+6.25₀₀₀₀₀₀₀₀₀₀₀₀₀₀₀, +6.4₀625₀₀₀₀₀₀₀₀₀₀₀₀],
#   [+9.375₀₀₀₀₀₀₀₀₀₀₀₀₀₀, +9.53125₀₀₀₀₀₀₀₀₀₀₀₀]],
#  9)

# %%
fig = figure(width=800, height=400)
x = np.linspace(-10, 10, 1000)
fig.line(x, f(x))
fig.add_layout(Span(location=0, dimension='width'))
for r in roots:
    _r, r_ = r
    fig.segment(x0=_r, y0=0, x1=r_, y1=0, color='red', line_width=10)
show(fig)
# Out:
#   <div id="a52cedd5-fee2-49ae-a77b-c5073e8d1aa0" data-root-id="p1044" style="display: contents;"></div>
